# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import xgboost as xgb
from xgboost import XGBClassifier, XGBRegressor
from xgboost import plot_importance
from matplotlib import pyplot
import shap

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.
from time import time
from tqdm import tqdm_notebook as tqdm
from collections import Counter
from scipy import stats
import lightgbm as lgb
from sklearn.metrics import cohen_kappa_score
from sklearn.model_selection import KFold, StratifiedKFold
import gc
import json
pd.set_option('display.max_columns', 1000)
# Out:
# /kaggle/input/data-science-bowl-2019/sample_submission.csv
# /kaggle/input/data-science-bowl-2019/specs.csv
# /kaggle/input/data-science-bowl-2019/train_labels.csv
# /kaggle/input/data-science-bowl-2019/train.csv
# /kaggle/input/data-science-bowl-2019/test.csv

# %% [markdown]
# # Objective
#
# * In the last notebook we create our baseline model including a feature selection part.
# * Cohen cappa score of 0.456 (lb) with a local cv score of 0.529
# * In this notebook we are going to add more features and remove others that i think they overfitt the train set and then check if our local cv score improve.
# * Next, we will check if this improvement aligns with the lb.

# %% [markdown]
# # Notes
# * Check the distribution of the target variable of the out of folds score and the prediction distribution. A good model should more or less have the same distribution.

# %%
def eval_qwk_lgb_regr(y_true, y_pred):
    """
    Fast cappa eval function for lgb.
    """
    dist = Counter(reduce_train['accuracy_group'])
    for k in dist:
        dist[k] /= len(reduce_train)
    reduce_train['accuracy_group'].hist()
    
    acum = 0
    bound = {}
    for i in range(3):
        acum += dist[i]
        bound[i] = np.percentile(y_pred, acum * 100)

    def classify(x):
        if x <= bound[0]:
            return 0
        elif x <= bound[1]:
            return 1
        elif x <= bound[2]:
            return 2
        else:
            return 3

    y_pred = np.array(list(map(classify, y_pred))).reshape(y_true.shape)

    return 'cappa', cohen_kappa_score(y_true, y_pred, weights='quadratic'), True

# %%
def cnt_miss(df):
    cnt = 0
    for e in range(len(df)):
        x = df['event_data'].iloc[e]
        y = json.loads(x)['misses']
        cnt += y
    return cnt

def get_4020_acc(df,counter_dict):
    
    for e in ['Cauldron Filler (Assessment)','Bird Measurer (Assessment)','Mushroom Sorter (Assessment)','Chest Sorter (Assessment)']:
        
        Assess_4020 = df[(df.event_code == 4020) & (df.title==activities_map[e])]   
        true_attempts_ = Assess_4020['event_data'].str.contains('true').sum()
        false_attempts_ = Assess_4020['event_data'].str.contains('false').sum()

        measure_assess_accuracy_ = true_attempts_/(true_attempts_+false_attempts_) if (true_attempts_+false_attempts_) != 0 else 0
        counter_dict[e+"_4020_accuracy"] += (counter_dict[e+"_4020_accuracy"] + measure_assess_accuracy_) / 2.0
    
    return counter_dict

# %%
def cohenkappa(ypred, y):
    y = y.get_label().astype("int")
    ypred = ypred.reshape((4, -1)).argmax(axis = 0)
    loss = cohenkappascore(y, y_pred, weights = 'quadratic')
    return "cappa", loss, True

# %%
def read_data():
    print('Reading train.csv file....')
    train = pd.read_csv('/kaggle/input/data-science-bowl-2019/train.csv')
    print('Training.csv file have {} rows and {} columns'.format(train.shape[0], train.shape[1]))

    print('Reading test.csv file....')
    test = pd.read_csv('/kaggle/input/data-science-bowl-2019/test.csv')
    print('Test.csv file have {} rows and {} columns'.format(test.shape[0], test.shape[1]))

    print('Reading train_labels.csv file....')
    train_labels = pd.read_csv('/kaggle/input/data-science-bowl-2019/train_labels.csv')
    print('Train_labels.csv file have {} rows and {} columns'.format(train_labels.shape[0], train_labels.shape[1]))

    print('Reading specs.csv file....')
    specs = pd.read_csv('/kaggle/input/data-science-bowl-2019/specs.csv')
    print('Specs.csv file have {} rows and {} columns'.format(specs.shape[0], specs.shape[1]))

    print('Reading sample_submission.csv file....')
    sample_submission = pd.read_csv('/kaggle/input/data-science-bowl-2019/sample_submission.csv')
    print('Sample_submission.csv file have {} rows and {} columns'.format(sample_submission.shape[0], sample_submission.shape[1]))
    return train, test, train_labels, specs, sample_submission

# %%
def encode_title(train, test, train_labels):
    # encode title
    train['title_event_code'] = list(map(lambda x, y: str(x) + '_' + str(y), train['title'], train['event_code']))
    test['title_event_code'] = list(map(lambda x, y: str(x) + '_' + str(y), test['title'], test['event_code']))
    all_title_event_code = list(set(train["title_event_code"].unique()).union(test["title_event_code"].unique()))
    
    train['type_world'] = list(map(lambda x, y: str(x) + '_' + str(y), train['type'], train['world']))
    test['type_world'] = list(map(lambda x, y: str(x) + '_' + str(y), test['type'], test['world']))
    all_type_world = list(set(train["type_world"].unique()).union(test["type_world"].unique()))
    
    # make a list with all the unique 'titles' from the train and test set
    list_of_user_activities = list(set(train['title'].unique()).union(set(test['title'].unique())))
    # make a list with all the unique 'event_code' from the train and test set
    list_of_event_code = list(set(train['event_code'].unique()).union(set(test['event_code'].unique())))
    list_of_event_id = list(set(train['event_id'].unique()).union(set(test['event_id'].unique())))
    # make a list with all the unique worlds from the train and test set
    list_of_worlds = list(set(train['world'].unique()).union(set(test['world'].unique())))
    # create a dictionary numerating the titles
    activities_map = dict(zip(list_of_user_activities, np.arange(len(list_of_user_activities))))
    activities_labels = dict(zip(np.arange(len(list_of_user_activities)), list_of_user_activities))
    activities_world = dict(zip(list_of_worlds, np.arange(len(list_of_worlds))))
    assess_titles = list(set(train[train['type'] == 'Assessment']['title'].value_counts().index).union(set(test[test['type'] == 'Assessment']['title'].value_counts().index)))
    # replace the text titles with the number titles from the dict
    train['title'] = train['title'].map(activities_map)
    test['title'] = test['title'].map(activities_map)
    train['world'] = train['world'].map(activities_world)
    test['world'] = test['world'].map(activities_world)
    train_labels['title'] = train_labels['title'].map(activities_map)
    win_code = dict(zip(activities_map.values(), (4100*np.ones(len(activities_map))).astype('int')))
    # then, it set one element, the 'Bird Measurer (Assessment)' as 4110, 10 more than the rest
    win_code[activities_map['Bird Measurer (Assessment)']] = 4110
    # convert text into datetime
    train['timestamp'] = pd.to_datetime(train['timestamp'])
    test['timestamp'] = pd.to_datetime(test['timestamp'])
    
    
    return train, test, train_labels, win_code, list_of_user_activities, list_of_event_code, activities_labels, assess_titles, list_of_event_id, all_title_event_code, activities_map,all_type_world

# %%
def get_data(user_sample, test_set=False):
    '''
    The user_sample is a DataFrame from train or test where the only one 
    installation_id is filtered
    And the test_set parameter is related with the labels processing, that is only requered
    if test_set=False
    '''
    # Constants and parameters declaration
    last_activity = 0
    
    user_activities_count = {'Clip':0, 'Activity': 0, 'Assessment': 0, 'Game':0}
    
    assess_4020_acc_dict = {'Cauldron Filler (Assessment)_4020_accuracy':0,
                                'Mushroom Sorter (Assessment)_4020_accuracy':0,
                                'Bird Measurer (Assessment)_4020_accuracy':0,
                                'Chest Sorter (Assessment)_4020_accuracy':0 }
    
    game_time_dict = {'Clip_gametime':0, 'Game_gametime':0, 'Activity_gametime':0, 'Assessment_gametime':0}
    
    # new features: time spent in each activity
    last_session_time_sec = 0
    accuracy_groups = {0:0, 1:0, 2:0, 3:0}
    all_assessments = []
    accumulated_accuracy_group = 0
    accumulated_accuracy = 0
    accumulated_correct_attempts = 0 
    accumulated_uncorrect_attempts = 0
    accumulated_actions = 0
    
    # Newly added features
    accumulated_game_miss = 0
    Cauldron_Filler_4025 = 0
    mean_game_round = 0
    mean_game_duration = 0 
    mean_game_level = 0
    Assessment_mean_event_count = 0
    Game_mean_event_count = 0
    Activity_mean_event_count = 0
    chest_assessment_uncorrect_sum = 0
    
    counter = 0
    time_first_activity = float(user_sample['timestamp'].values[0])
    durations = []
    last_accuracy_title = {'acc_' + title: -1 for title in assess_titles}
    event_code_count: Dict[str, int] = {ev: 0 for ev in list_of_event_code}
    event_id_count: Dict[str, int] = {eve: 0 for eve in list_of_event_id}
    title_count: Dict[str, int] = {eve: 0 for eve in activities_labels.values()} 
    title_event_code_count: Dict[str, int] = {t_eve: 0 for t_eve in all_title_event_code}
    type_world_count: Dict[str, int] = {w_eve: 0 for w_eve in all_type_world}
        
    # last features
    sessions_count = 0
    
    # itarates through each session of one instalation_id
    for i, session in user_sample.groupby('game_session', sort=False):
        # i = game_session_id
        # session is a DataFrame that contain only one game_session
        
        # get some sessions information
        session_type = session['type'].iloc[0]
        session_title = session['title'].iloc[0]
        session_title_text = activities_labels[session_title]
                    
        if session_type=="Activity":
            Activity_mean_event_count = (Activity_mean_event_count + session['event_count'].iloc[-1])/2.0
            
        if session_type=="Game":
            
            Game_mean_event_count = (Game_mean_event_count + session['event_count'].iloc[-1])/2.0
            
            game_s = session[session.event_code == 2030]   
            misses_cnt = cnt_miss(game_s)
            accumulated_game_miss += misses_cnt
            
            try:
                game_round = json.loads(session['event_data'].iloc[-1])["round"]
                mean_game_round =  (mean_game_round + game_round)/2.0
            except:
                pass

            try:
                game_duration = json.loads(session['event_data'].iloc[-1])["duration"]
                mean_game_duration = (mean_game_duration + game_duration) /2.0
            except:
                pass
            
            try:
                game_level = json.loads(session['event_data'].iloc[-1])["level"]
                mean_game_level = (mean_game_level + game_level) /2.0
            except:
                pass
            
        # for each assessment, and only this kind off session, the features below are processed
        # and a register are generated
        if (session_type == 'Assessment') & (test_set or len(session)>1):
            # search for event_code 4100, that represents the assessments trial
            all_attempts = session.query(f'event_code == {win_code[session_title]}')
            # then, check the numbers of wins and the number of losses
            true_attempts = all_attempts['event_data'].str.contains('true').sum()
            false_attempts = all_attempts['event_data'].str.contains('false').sum()
            # copy a dict to use as feature template, it's initialized with some itens: 
            # {'Clip':0, 'Activity': 0, 'Assessment': 0, 'Game':0}
            features = user_activities_count.copy()
            features.update(last_accuracy_title.copy())
            features.update(event_code_count.copy())
            features.update(event_id_count.copy())
            features.update(title_count.copy())
            features.update(game_time_dict.copy())
            features.update(title_event_code_count.copy())
            features.update(last_accuracy_title.copy())
            features.update(assess_4020_acc_dict.copy())
            features.update(type_world_count.copy())
            
            features['installation_session_count'] = sessions_count
            features['accumulated_game_miss'] = accumulated_game_miss
            features['mean_game_round'] = mean_game_round
            features['mean_game_duration'] = mean_game_duration
            features['mean_game_level'] = mean_game_level
            features['Assessment_mean_event_count'] = Assessment_mean_event_count
            features['Game_mean_event_count'] = Game_mean_event_count
            features['Activity_mean_event_count'] = Activity_mean_event_count
            features['chest_assessment_uncorrect_sum'] = chest_assessment_uncorrect_sum
            
            variety_features = [('var_event_code', event_code_count),
                              ('var_event_id', event_id_count),
                               ('var_title', title_count),
                               ('var_title_event_code', title_event_code_count),
                                ('var_type_world', type_world_count)]
            
            for name, dict_counts in variety_features:
                arr = np.array(list(dict_counts.values()))
                features[name] = np.count_nonzero(arr)
                 
            # get installation_id for aggregated features
            features['installation_id'] = session['installation_id'].iloc[-1]
            # add title as feature, remembering that title represents the name of the game
            features['session_title'] = session['title'].iloc[0]
            # the 4 lines below add the feature of the history of the trials of this player
            # this is based on the all time attempts so far, at the moment of this assessment
            features['accumulated_correct_attempts'] = accumulated_correct_attempts
            features['accumulated_uncorrect_attempts'] = accumulated_uncorrect_attempts
            accumulated_correct_attempts += true_attempts 
            accumulated_uncorrect_attempts += false_attempts
            # the time spent in the app so far
            if durations == []:
                features['duration_mean'] = 0
                features['duration_std'] = 0
            else:
                features['duration_mean'] = np.mean(durations)
                features['duration_std'] = np.std(durations)
            durations.append((session.iloc[-1, 2] - session.iloc[0, 2] ).seconds)
            # the accurace is the all time wins divided by the all time attempts
            features['accumulated_accuracy'] = accumulated_accuracy/counter if counter > 0 else 0
            
            features['Cauldron_Filler_4025'] = Cauldron_Filler_4025/counter if counter > 0 else 0
            ####################
            Assess_4025 = session[(session.event_code == 4025) & (session.title=='Cauldron Filler (Assessment)')]   
            true_attempts_ = Assess_4025['event_data'].str.contains('true').sum()
            false_attempts_ = Assess_4025['event_data'].str.contains('false').sum()

            cau_assess_accuracy_ = true_attempts_/(true_attempts_+false_attempts_) if (true_attempts_+false_attempts_) != 0 else 0
            Cauldron_Filler_4025 += cau_assess_accuracy_
            
            chest_assessment_uncorrect_sum += len(session[session.event_id=="df4fe8b6"])
            
            Assessment_mean_event_count = (Assessment_mean_event_count + session['event_count'].iloc[-1])/2.0
            ##############################
            accuracy = true_attempts/(true_attempts+false_attempts) if (true_attempts+false_attempts) != 0 else 0
            accumulated_accuracy += accuracy
            last_accuracy_title['acc_' + session_title_text] = accuracy
            # a feature of the current accuracy categorized
            # it is a counter of how many times this player was in each accuracy group
            if accuracy == 0:
                features['accuracy_group'] = 0
            elif accuracy == 1:
                features['accuracy_group'] = 3
            elif accuracy == 0.5:
                features['accuracy_group'] = 2
            else:
                features['accuracy_group'] = 1
            features.update(accuracy_groups)
            accuracy_groups[features['accuracy_group']] += 1
            # mean of the all accuracy groups of this player
            features['accumulated_accuracy_group'] = accumulated_accuracy_group/counter if counter > 0 else 0
            accumulated_accuracy_group += features['accuracy_group']
            # how many actions the player has done so far, it is initialized as 0 and updated some lines below
            features['accumulated_actions'] = accumulated_actions
            
            # there are some conditions to allow this features to be inserted in the datasets
            # if it's a test set, all sessions belong to the final dataset
            # it it's a train, needs to be passed throught this clausule: session.query(f'event_code == {win_code[session_title]}')
            # that means, must exist an event_code 4100 or 4110
            if test_set:
                all_assessments.append(features)
            elif true_attempts+false_attempts > 0:
                all_assessments.append(features)
                
            counter += 1
        
        # end session_type=="Assessment"
        
        sessions_count += 1
        # this piece counts how many actions was made in each event_code so far
        def update_counters(counter: dict, col: str):
                num_of_session_count = Counter(session[col])
                for k in num_of_session_count.keys():
                    x = k
                    if col == 'title':
                        x = activities_labels[k]
                    counter[x] += num_of_session_count[k]
                return counter
            
        event_code_count = update_counters(event_code_count, "event_code")
        event_id_count = update_counters(event_id_count, "event_id")
        title_count = update_counters(title_count, 'title')
        title_event_code_count = update_counters(title_event_code_count, 'title_event_code')
        type_world_count = update_counters(type_world_count, 'type_world')
        
        assess_4020_acc_dict = get_4020_acc(session , assess_4020_acc_dict)
        game_time_dict[session_type+'_gametime'] = (game_time_dict[session_type+'_gametime'] + (session['game_time'].iloc[-1]/1000.0))/2.0
        
        # counts how many actions the player has done so far, used in the feature of the same name
        accumulated_actions += len(session)
        if last_activity != session_type:
            user_activities_count[session_type] += 1
            last_activitiy = session_type 
                        
    # if it't the test_set, only the last assessment must be predicted, the previous are scraped
    if test_set:
        return all_assessments[-1]
    # in the train_set, all assessments goes to the dataset
    return all_assessments

# %%
def get_train_and_test(train, test):
    compiled_train = []
    compiled_test = []
    for i, (ins_id, user_sample) in tqdm(enumerate(train.groupby('installation_id', sort = False)), total = 17000):
        compiled_train += get_data(user_sample)
    for ins_id, user_sample in tqdm(test.groupby('installation_id', sort = False), total = 1000):
        test_data = get_data(user_sample, test_set = True)
        compiled_test.append(test_data)
    reduce_train = pd.DataFrame(compiled_train)
    reduce_test = pd.DataFrame(compiled_test)
    categoricals = ['session_title']
    return reduce_train, reduce_test, categoricals

# %%
def run_feature_selection(reduce_train, reduce_test, usefull_features, new_features):
    kf = StratifiedKFold(n_splits = 10, shuffle = True, random_state = 42)
    target = 'accuracy_group'
    oof_pred = np.zeros((len(reduce_train), 4))
    for fold, (tr_ind, val_ind) in enumerate(kf.split(reduce_train, reduce_train[target])):
        print('Fold {}'.format(fold + 1))
        x_train, x_val = reduce_train[usefull_features].iloc[tr_ind], reduce_train[usefull_features].iloc[val_ind]
        y_train, y_val = reduce_train[target][tr_ind], reduce_train[target][val_ind]
        train_set = lgb.Dataset(x_train, y_train, categorical_feature = categoricals)
        val_set = lgb.Dataset(x_val, y_val, categorical_feature = categoricals)

        params = {
            'learning_rate': 0.01,
            'metric': 'multiclass',
            'objective': 'multiclass',
            'num_classes': 4,
            'feature_fraction': 0.75,
            'subsample': 0.75,
            'n_jobs': -1,
            'seed': 50,
            'max_depth': 10
        }

        model = lgb.train(params, train_set, num_boost_round = 100000, early_stopping_rounds = 100, 
                          valid_sets=[train_set, val_set], verbose_eval = 500)
        oof_pred[val_ind] = model.predict(x_val)
    # using cohen_kappa because it's the evaluation metric of the competition
    loss_score = cohen_kappa_score(reduce_train[target], np.argmax(oof_pred, axis = 1), weights = 'quadratic')
    score = loss_score
    usefull_new_features = []
    for i in new_features:
        oof_pred = np.zeros((len(reduce_train), 4))
        evaluating_features = usefull_features + usefull_new_features + [i]
        print('Evaluating {} column'.format(i))
        print('Out best cohen kappa score is : {}'.format(score))
        for fold, (tr_ind, val_ind) in enumerate(kf.split(reduce_train, reduce_train[target])):
            print('Fold {}'.format(fold + 1))
            x_train, x_val = reduce_train[evaluating_features].iloc[tr_ind], reduce_train[evaluating_features].iloc[val_ind]
            y_train, y_val = reduce_train[target][tr_ind], reduce_train[target][val_ind]
            train_set = lgb.Dataset(x_train, y_train, categorical_feature = categoricals)
            val_set = lgb.Dataset(x_val, y_val, categorical_feature = categoricals)

            model = lgb.train(params, train_set, num_boost_round = 100000, early_stopping_rounds = 100, 
                              valid_sets=[train_set, val_set], verbose_eval = 500)
            oof_pred[val_ind] = model.predict(x_val)
        loss_score = cohen_kappa_score(reduce_train[target], np.argmax(oof_pred, axis = 1), weights = 'quadratic')
        print('Our new cohen kappa score is : {}'.format(loss_score))
        if loss_score > score:
            print('Feature {} is usefull, adding feature to usefull_new_features_list'.format(i))
            usefull_new_features.append(i)
            score = loss_score
        else:
            print('Feature {} is useless'.format(i))
        gc.collect()
    print('The best features are: ', usefull_new_features)
    print('Our best cohen kappa score is : ', score)

    return usefull_features + usefull_new_features

# %%
def run_lgb_regression(reduce_train, reduce_test, usefull_features, n_splits):
    kf = StratifiedKFold(n_splits=n_splits, shuffle = True, random_state = 42)
    target = 'accuracy_group'
    oof_pred = np.zeros((len(reduce_train), ))
    y_pred = np.zeros((len(reduce_test), ))
    for fold, (tr_ind, val_ind) in enumerate(kf.split(reduce_train, reduce_train[target])):
        print('Fold {}'.format(fold + 1))
        x_train, x_val = reduce_train[usefull_features].iloc[tr_ind], reduce_train[usefull_features].iloc[val_ind]
        y_train, y_val = reduce_train[target][tr_ind], reduce_train[target][val_ind]
        train_set = lgb.Dataset(x_train, y_train, categorical_feature=categoricals)
        val_set = lgb.Dataset(x_val, y_val, categorical_feature=categoricals)

        params = {'n_estimators':5000,
                    'boosting_type': 'gbdt',
                    'objective': 'regression',
                    'metric': 'rmse',
                    'subsample': 0.75,
                    'subsample_freq': 1,
                    'learning_rate': 0.01,
                    'feature_fraction': 0.9,
                    'max_depth': 15,
                    'lambda_l1': 1,  
                    'lambda_l2': 1,
                    'verbose': 100,
                    'early_stopping_rounds': 200
                    }

        model = lgb.train(params, train_set, num_boost_round = 1000000, early_stopping_rounds = 300, 
                          valid_sets=[train_set, val_set], verbose_eval = 100)
        oof_pred[val_ind] = model.predict(x_val)
        y_pred += model.predict(reduce_test[usefull_features]) / n_splits
    _, loss_score, _ = eval_qwk_lgb_regr(reduce_train[target], oof_pred)
    print('Our oof cohen kappa score is: ', loss_score)

    return y_pred

# %%
def run_xgb_regression(reduce_train, reduce_test, usefull_features, n_splits):
    kf = StratifiedKFold(n_splits=n_splits, shuffle = True, random_state = 42)
    target = 'accuracy_group'
    oof_pred = np.zeros((len(reduce_train), ))
    y_pred = np.zeros((len(reduce_test), ))
    for fold, (tr_ind, val_ind) in enumerate(kf.split(reduce_train, reduce_train[target])):
        print('Fold {}'.format(fold + 1))
        x_train, x_val = reduce_train[usefull_features].iloc[tr_ind], reduce_train[usefull_features].iloc[val_ind]
        y_train, y_val = reduce_train[target][tr_ind], reduce_train[target][val_ind]
        xgb_train = xgb.DMatrix(x_train, y_train)
        xgb_eval = xgb.DMatrix(x_val, y_val)

        pars = {
            'colsample_bytree': 0.8,                 
            'learning_rate': 0.01,
            'max_depth': 10,
            'subsample': 1,
            'objective':'reg:squarederror',
            #'eval_metric':'rmse',
            'min_child_weight':3,
            'gamma':0.25,
            'n_estimators':5000
        }

        model = xgb.train(pars,
                      xgb_train,
                      num_boost_round=5000,
                      evals=[(xgb_train, 'train'), (xgb_eval, 'val')],
                      verbose_eval=100,
                      early_stopping_rounds=200
                     )
        
        val_X=xgb.DMatrix(x_val)
        oof_pred[val_ind] = model.predict(val_X)
        test_X = xgb.DMatrix(reduce_test[usefull_features])
        y_pred += model.predict(test_X) / n_splits
    _, loss_score, _ = eval_qwk_lgb_regr(reduce_train[target], oof_pred)
    print('Our oof cohen kappa score is: ', loss_score)

    return y_pred

# %%
#import gc
#del reduce_train, reduce_test
#gc.collect()

# %%
# read data
train, test, train_labels, specs, sample_submission = read_data()
# get usefull dict with maping encode
train, test, train_labels, win_code, list_of_user_activities, list_of_event_code, activities_labels, assess_titles, list_of_event_id, all_title_event_code, activities_map,all_type_world = encode_title(train, test, train_labels)
# tranform function to get the train and test set
# tranform function to get the train and test set
reduce_train, reduce_test, categoricals = get_train_and_test(train, test)
# Out:
# Reading train.csv file....
# Training.csv file have 11341042 rows and 11 columns
# Reading test.csv file....
# Test.csv file have 1156414 rows and 11 columns
# Reading train_labels.csv file....
# Train_labels.csv file have 17690 rows and 7 columns
# Reading specs.csv file....
# Specs.csv file have 386 rows and 3 columns
# Reading sample_submission.csv file....
# Sample_submission.csv file have 1000 rows and 2 columns
# HBox(children=(IntProgress(value=0, max=17000), HTML(value='')))
# /opt/conda/lib/python3.6/site-packages/pandas/core/ops/__init__.py:1115: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)

# %%
def plot_train_test_comp(feature):
    BINS = 50
    #data = reduce_train[reduce_train['accuracy_group'] == 3][feature]
    data = reduce_train[feature]
    train_mean = data.mean()
    perc_90 = np.percentile(data, 95)
    plt.hist(np.clip(data, 0, perc_90), bins=BINS, color='blue', alpha=0.5, weights=np.ones(len(data)) / len(data))
    data = reduce_test[feature] 
    test_mean = data.mean()
    ajust_factor = train_mean / test_mean
    plt.hist(np.clip(data * ajust_factor, 0, perc_90), bins=BINS, color='red', alpha=0.5, weights=np.ones(len(data)) / len(data))
    plt.show()

plot_train_test_comp('Clip')

# %%
# pd.set_option('display.max_columns', None)
# pd.set_option('display.max_rows', None)

# %%
 reduce_train.shape
# Out:
# (17690, 932)

# %%
# call feature engineering function
features = reduce_train.loc[(reduce_train.sum(axis=1) != 0), (reduce_train.sum(axis=0) != 0)].columns # delete useless columns
features = [x for x in features if x not in ['accuracy_group', 'installation_id']]

# %%
counter = 0
to_remove = []
for feat_a in features:
    for feat_b in features:
        if feat_a != feat_b and feat_a not in to_remove and feat_b not in to_remove:
            c = np.corrcoef(reduce_train[feat_a], reduce_train[feat_b])[0][1]
            if c >= 1:
                counter += 1
                to_remove.append(feat_a)
                print('{}: FEAT_A: {} FEAT_B: {} - Correlation: {}'.format(counter, feat_a, feat_b, c))
# Out:
# 1: FEAT_A: Clip FEAT_B: 27253bdc - Correlation: 1.0
# /opt/conda/lib/python3.6/site-packages/numpy/lib/function_base.py:2530: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[:, None]
# 2: FEAT_A: 5000 FEAT_B: a6d66e51 - Correlation: 1.0
# 3: FEAT_A: 4031 FEAT_B: 1996c610 - Correlation: 1.0
# 4: FEAT_A: 2000 FEAT_B: installation_session_count - Correlation: 1.0
# 5: FEAT_A: 4050 FEAT_B: a1192f43 - Correlation: 1.0
# 6: FEAT_A: 4220 FEAT_B: 1340b8d7 - Correlation: 1.0
# 7: FEAT_A: 3b2048ee FEAT_B: Leaf Leader_4095 - Correlation: 1.0
# 8: FEAT_A: 46b50ba8 FEAT_B: Happy Camel_4095 - Correlation: 1.0
# 9: FEAT_A: c74f40cd FEAT_B: Mushroom Sorter (Assessment)_3121 - Correlation: 1.0
# 10: FEAT_A: a0faea5d FEAT_B: Bubble Bath_4070 - Correlation: 1.0
# 11: FEAT_A: 6043a2b4 FEAT_B: All Star Sorting_4090 - Correlation: 1.0
# 12: FEAT_A: 38074c54 FEAT_B: 222660ff - Correlation: 1.0
# 13: FEAT_A: 53c6e11a FEAT_B: Leaf Leader_2075 - Correlation: 1.0
# 14: FEAT_A: 6d90d394 FEAT_B: Scrub-A-Dub_2000 - Correlation: 1.0
# 15: FEAT_A: 1375ccb7 FEAT_B: Bird Measurer (Assessment)_3010 - Correlation: 1.0
# 16: FEAT_A: 461eace6 FEAT_B: Egg Dropper (Activity)_4020 - Correlation: 1.0
# 17: FEAT_A: e64e2cfd FEAT_B: Watering Hole (Activity)_2000 - Correlation: 1.0
# 18: FEAT_A: acf5c23f FEAT_B: Cart Balancer (Assessment)_4070 - Correlation: 1.0
# 19: FEAT_A: 58a0de5c FEAT_B: Air Show_3121 - Correlation: 1.0
# 20: FEAT_A: 0d18d96c FEAT_B: Mushroom Sorter (Assessment)_4035 - Correlation: 1.0
# 21: FEAT_A: 47026d5f FEAT_B: Chow Time_3021 - Correlation: 1.0
# 22: FEAT_A: 8fee50e2 FEAT_B: Bird Measurer (Assessment)_4020 - Correlation: 1.0
# 23: FEAT_A: e04fb33d FEAT_B: Air Show_3120 - Correlation: 1.0
# 24: FEAT_A: 1340b8d7 FEAT_B: Bubble Bath_4220 - Correlation: 1.0
# 25: FEAT_A: 1996c610 FEAT_B: Dino Drink_4031 - Correlation: 1.0
# 26: FEAT_A: 29bdd9ba FEAT_B: Dino Dive_2000 - Correlation: 1.0
# 27: FEAT_A: c2baf0bd FEAT_B: Happy Camel_2020 - Correlation: 1.0
# 28: FEAT_A: 3afb49e6 FEAT_B: Chest Sorter (Assessment)_3021 - Correlation: 1.0
# 29: FEAT_A: 63f13dd7 FEAT_B: Chow Time_2020 - Correlation: 1.0
# 30: FEAT_A: 6f4bd64e FEAT_B: Air Show_4090 - Correlation: 1.0
# 31: FEAT_A: 3393b68b FEAT_B: Bird Measurer (Assessment)_2010 - Correlation: 1.0
# 32: FEAT_A: d3640339 FEAT_B: Dino Dive_4090 - Correlation: 1.0
# 33: FEAT_A: 857f21c0 FEAT_B: Bubble Bath_4040 - Correlation: 1.0
# 34: FEAT_A: e9c52111 FEAT_B: Bottle Filler (Activity)_2030 - Correlation: 1.0
# 35: FEAT_A: cfbd47c8 FEAT_B: Chow Time_4030 - Correlation: 1.0
# 36: FEAT_A: db02c830 FEAT_B: Mushroom Sorter (Assessment)_2025 - Correlation: 1.0
# 37: FEAT_A: 3bb91dda FEAT_B: Bubble Bath_4020 - Correlation: 1.0
# 38: FEAT_A: eb2c19cd FEAT_B: Mushroom Sorter (Assessment)_4090 - Correlation: 1.0
# 39: FEAT_A: 895865f3 FEAT_B: Bubble Bath_2030 - Correlation: 1.0
# 40: FEAT_A: d185d3ea FEAT_B: Chow Time_4035 - Correlation: 1.0
# 41: FEAT_A: 709b1251 FEAT_B: Dino Dive_3121 - Correlation: 1.0
# 42: FEAT_A: 16dffff1 FEAT_B: Dino Drink_2030 - Correlation: 1.0
# 43: FEAT_A: c189aaf2 FEAT_B: Happy Camel_2083 - Correlation: 1.0
# 44: FEAT_A: a8876db3 FEAT_B: Cart Balancer (Assessment)_3021 - Correlation: 1.0
# 45: FEAT_A: 14de4c5d FEAT_B: Air Show_4100 - Correlation: 1.0
# 46: FEAT_A: 611485c5 FEAT_B: Fireworks (Activity)_4080 - Correlation: 1.0
# 47: FEAT_A: 1cc7cfca FEAT_B: All Star Sorting_4030 - Correlation: 1.0
# 48: FEAT_A: a1192f43 FEAT_B: Crystals Rule_4050 - Correlation: 1.0
# 49: FEAT_A: 9b23e8ee FEAT_B: 736f9581 - Correlation: 1.0
# 50: FEAT_A: 3ccd3f02 FEAT_B: Chest Sorter (Assessment)_3110 - Correlation: 1.0
# 51: FEAT_A: 3dfd4aa4 FEAT_B: Mushroom Sorter (Assessment)_2020 - Correlation: 1.0
# 52: FEAT_A: 4901243f FEAT_B: Fireworks (Activity)_2000 - Correlation: 1.0
# 53: FEAT_A: 90efca10 FEAT_B: Bottle Filler (Activity)_4020 - Correlation: 1.0
# 54: FEAT_A: a8efe47b FEAT_B: Chest Sorter (Assessment)_4030 - Correlation: 1.0
# 55: FEAT_A: 7ad3efc6 FEAT_B: Cart Balancer (Assessment)_2000 - Correlation: 1.0
# 56: FEAT_A: 4d911100 FEAT_B: Dino Drink_3121 - Correlation: 1.0
# 57: FEAT_A: 15eb4a7d FEAT_B: Bubble Bath_3110 - Correlation: 1.0
# 58: FEAT_A: 28520915 FEAT_B: Cauldron Filler (Assessment)_2030 - Correlation: 1.0
# 59: FEAT_A: 5c3d2b2f FEAT_B: Scrub-A-Dub_4020 - Correlation: 1.0
# 60: FEAT_A: 6088b756 FEAT_B: Dino Dive_2070 - Correlation: 1.0
# 61: FEAT_A: 9b01374f FEAT_B: Flower Waterer (Activity)_2000 - Correlation: 1.0
# 62: FEAT_A: 792530f8 FEAT_B: Dino Drink_4030 - Correlation: 1.0
# 63: FEAT_A: e5734469 FEAT_B: Dino Drink_3020 - Correlation: 1.0
# 64: FEAT_A: 736f9581 FEAT_B: Egg Dropper (Activity)_2000 - Correlation: 1.0
# 65: FEAT_A: 4ef8cdd3 FEAT_B: Chow Time_4020 - Correlation: 1.0
# 66: FEAT_A: 69fdac0a FEAT_B: Happy Camel_3110 - Correlation: 1.0
# 67: FEAT_A: 0330ab6a FEAT_B: Chow Time_3020 - Correlation: 1.0
# 68: FEAT_A: a44b10dc FEAT_B: Flower Waterer (Activity)_4070 - Correlation: 1.0
# 69: FEAT_A: 3d8c61b0 FEAT_B: Happy Camel_4030 - Correlation: 1.0
# 70: FEAT_A: c51d8688 FEAT_B: Pan Balance_3120 - Correlation: 1.0
# 71: FEAT_A: 7040c096 FEAT_B: Scrub-A-Dub_4010 - Correlation: 1.0
# 72: FEAT_A: 5154fc30 FEAT_B: Crystals Rule_3010 - Correlation: 1.0
# 73: FEAT_A: 2b058fe3 FEAT_B: Cauldron Filler (Assessment)_2010 - Correlation: 1.0
# 74: FEAT_A: 36fa3ebe FEAT_B: Happy Camel_2030 - Correlation: 1.0
# 75: FEAT_A: d2e9262e FEAT_B: Watering Hole (Activity)_4020 - Correlation: 1.0
# 76: FEAT_A: ad2fc29c FEAT_B: Bird Measurer (Assessment)_3020 - Correlation: 1.0
# 77: FEAT_A: 5c2f29ca FEAT_B: Cart Balancer (Assessment)_4020 - Correlation: 1.0
# 78: FEAT_A: 84538528 FEAT_B: Sandcastle Builder (Activity)_4020 - Correlation: 1.0
# 79: FEAT_A: f93fc684 FEAT_B: Chow Time_4010 - Correlation: 1.0
# 80: FEAT_A: c1cac9a2 FEAT_B: Scrub-A-Dub_2081 - Correlation: 1.0
# 81: FEAT_A: 71fe8f75 FEAT_B: Bug Measurer (Activity)_3110 - Correlation: 1.0
# 82: FEAT_A: daac11b0 FEAT_B: All Star Sorting_3021 - Correlation: 1.0
# 83: FEAT_A: 4a4c3d21 FEAT_B: Bird Measurer (Assessment)_4025 - Correlation: 1.0
# 84: FEAT_A: f50fc6c1 FEAT_B: Watering Hole (Activity)_4021 - Correlation: 1.0
# 85: FEAT_A: df4fe8b6 FEAT_B: Chest Sorter (Assessment)_3120 - Correlation: 1.0
# 86: FEAT_A: e694a35b FEAT_B: Fireworks (Activity)_4020 - Correlation: 1.0
# 87: FEAT_A: 907a054b FEAT_B: Pan Balance_3020 - Correlation: 1.0
# 88: FEAT_A: 83c6c409 FEAT_B: Mushroom Sorter (Assessment)_2035 - Correlation: 1.0
# 89: FEAT_A: 9de5e594 FEAT_B: Dino Dive_3020 - Correlation: 1.0
# 90: FEAT_A: e37a2b78 FEAT_B: Bird Measurer (Assessment)_3120 - Correlation: 1.0
# 91: FEAT_A: 6f445b57 FEAT_B: Chow Time_4080 - Correlation: 1.0
# 92: FEAT_A: bd701df8 FEAT_B: Watering Hole (Activity)_3110 - Correlation: 1.0
# 93: FEAT_A: 0a08139c FEAT_B: Bug Measurer (Activity)_3010 - Correlation: 1.0
# 94: FEAT_A: 5b49460a FEAT_B: 155f62a4 - Correlation: 1.0
# 95: FEAT_A: 222660ff FEAT_B: Chest Sorter (Assessment)_2010 - Correlation: 1.0
# 96: FEAT_A: 7525289a FEAT_B: Bird Measurer (Assessment)_3121 - Correlation: 1.0
# 97: FEAT_A: 08fd73f3 FEAT_B: Scrub-A-Dub_2030 - Correlation: 1.0
# 98: FEAT_A: 88d4a5be FEAT_B: Mushroom Sorter (Assessment)_3120 - Correlation: 1.0
# 99: FEAT_A: f806dc10 FEAT_B: Dino Drink_2020 - Correlation: 1.0
# 100: FEAT_A: b1d5101d FEAT_B: All Star Sorting_4095 - Correlation: 1.0
# 101: FEAT_A: d2278a3b FEAT_B: Bottle Filler (Activity)_2000 - Correlation: 1.0
# 102: FEAT_A: c7f7f0e1 FEAT_B: Bug Measurer (Activity)_2000 - Correlation: 1.0
# 103: FEAT_A: b2e5b0f1 FEAT_B: Cart Balancer (Assessment)_2010 - Correlation: 1.0
# 104: FEAT_A: 06372577 FEAT_B: Air Show_2060 - Correlation: 1.0
# 105: FEAT_A: fcfdffb6 FEAT_B: Flower Waterer (Activity)_4022 - Correlation: 1.0
# 106: FEAT_A: e080a381 FEAT_B: Pan Balance_4090 - Correlation: 1.0
# 107: FEAT_A: 250513af FEAT_B: Pan Balance_3021 - Correlation: 1.0
# 108: FEAT_A: f3cd5473 FEAT_B: Pan Balance_4070 - Correlation: 1.0
# 109: FEAT_A: e3ff61fb FEAT_B: Dino Dive_3021 - Correlation: 1.0
# 110: FEAT_A: 55115cbd FEAT_B: Bubble Bath_3121 - Correlation: 1.0
# 111: FEAT_A: 37db1c2f FEAT_B: Happy Camel_4045 - Correlation: 1.0
# 112: FEAT_A: 6cf7d25c FEAT_B: Pan Balance_3010 - Correlation: 1.0
# 113: FEAT_A: 86c924c4 FEAT_B: Crystals Rule_4020 - Correlation: 1.0
# 114: FEAT_A: b2dba42b FEAT_B: Sandcastle Builder (Activity)_3010 - Correlation: 1.0
# 115: FEAT_A: 15a43e5b FEAT_B: Bottle Filler (Activity)_4070 - Correlation: 1.0
# 116: FEAT_A: b5053438 FEAT_B: Cauldron Filler (Assessment)_3121 - Correlation: 1.0
# 117: FEAT_A: 29f54413 FEAT_B: Leaf Leader_2060 - Correlation: 1.0
# 118: FEAT_A: 31973d56 FEAT_B: Cart Balancer (Assessment)_3120 - Correlation: 1.0
# 119: FEAT_A: cdd22e43 FEAT_B: Chicken Balancer (Activity)_4035 - Correlation: 1.0
# 120: FEAT_A: 7ab78247 FEAT_B: Egg Dropper (Activity)_3010 - Correlation: 1.0
# 121: FEAT_A: 86ba578b FEAT_B: Leaf Leader_2070 - Correlation: 1.0
# 122: FEAT_A: 6077cc36 FEAT_B: Bird Measurer (Assessment)_4080 - Correlation: 1.0
# 123: FEAT_A: 262136f4 FEAT_B: Leaf Leader_4020 - Correlation: 1.0
# 124: FEAT_A: 5de79a6a FEAT_B: Cart Balancer (Assessment)_3020 - Correlation: 1.0
# 125: FEAT_A: 5348fd84 FEAT_B: Cauldron Filler (Assessment)_4040 - Correlation: 1.0
# 126: FEAT_A: c0415e5c FEAT_B: Dino Dive_4020 - Correlation: 1.0
# 127: FEAT_A: 02a42007 FEAT_B: Fireworks (Activity)_4030 - Correlation: 1.0
# 128: FEAT_A: 37ee8496 FEAT_B: Cauldron Filler (Assessment)_4030 - Correlation: 1.0
# 129: FEAT_A: a8a78786 FEAT_B: Happy Camel_3121 - Correlation: 1.0
# 130: FEAT_A: 731c0cbe FEAT_B: Bird Measurer (Assessment)_4090 - Correlation: 1.0
# 131: FEAT_A: d02b7a8e FEAT_B: All Star Sorting_4035 - Correlation: 1.0
# 132: FEAT_A: 1f19558b FEAT_B: All Star Sorting_3121 - Correlation: 1.0
# 133: FEAT_A: c7fe2a55 FEAT_B: Happy Camel_3021 - Correlation: 1.0
# 134: FEAT_A: c54cf6c5 FEAT_B: Bubble Bath_2025 - Correlation: 1.0
# 135: FEAT_A: dcb55a27 FEAT_B: Air Show_4110 - Correlation: 1.0
# 136: FEAT_A: 7ec0c298 FEAT_B: Chow Time_3010 - Correlation: 1.0
# 137: FEAT_A: 4bb2f698 FEAT_B: Chicken Balancer (Activity)_4070 - Correlation: 1.0
# 138: FEAT_A: 9d4e7b25 FEAT_B: Cart Balancer (Assessment)_4040 - Correlation: 1.0
# 139: FEAT_A: 46cd75b4 FEAT_B: Chicken Balancer (Activity)_4022 - Correlation: 1.0
# 140: FEAT_A: 65a38bf7 FEAT_B: Cart Balancer (Assessment)_2020 - Correlation: 1.0
# 141: FEAT_A: 15ba1109 FEAT_B: Air Show_2000 - Correlation: 1.0
# 142: FEAT_A: bbfe0445 FEAT_B: Flower Waterer (Activity)_3110 - Correlation: 1.0
# 143: FEAT_A: 8f094001 FEAT_B: Bubble Bath_4045 - Correlation: 1.0
# 144: FEAT_A: 8d84fa81 FEAT_B: Bubble Bath_4010 - Correlation: 1.0
# 145: FEAT_A: 56bcd38d FEAT_B: Chicken Balancer (Activity)_4030 - Correlation: 1.0
# 146: FEAT_A: 4c2ec19f FEAT_B: Egg Dropper (Activity)_4025 - Correlation: 1.0
# 147: FEAT_A: f32856e4 FEAT_B: Leaf Leader_2020 - Correlation: 1.0
# 148: FEAT_A: f56e0afc FEAT_B: Bird Measurer (Assessment)_2000 - Correlation: 1.0
# 149: FEAT_A: 3bb91ced FEAT_B: Happy Camel_2081 - Correlation: 1.0
# 150: FEAT_A: 5859dfb6 FEAT_B: Bubble Bath_3120 - Correlation: 1.0
# 151: FEAT_A: c7128948 FEAT_B: Mushroom Sorter (Assessment)_4040 - Correlation: 1.0
# 152: FEAT_A: d9c005dd FEAT_B: Happy Camel_2000 - Correlation: 1.0
# 153: FEAT_A: 56817e2b FEAT_B: Chow Time_2030 - Correlation: 1.0
# 154: FEAT_A: ac92046e FEAT_B: Scrub-A-Dub_3120 - Correlation: 1.0
# 155: FEAT_A: a5e9da97 FEAT_B: Pan Balance_4100 - Correlation: 1.0
# 156: FEAT_A: 7fd1ac25 FEAT_B: Egg Dropper (Activity)_4080 - Correlation: 1.0
# 157: FEAT_A: ca11f653 FEAT_B: All Star Sorting_2030 - Correlation: 1.0
# 158: FEAT_A: 9e34ea74 FEAT_B: Egg Dropper (Activity)_4070 - Correlation: 1.0
# 159: FEAT_A: 2a444e03 FEAT_B: Pan Balance_4030 - Correlation: 1.0
# 160: FEAT_A: d88e8f25 FEAT_B: Scrub-A-Dub_3020 - Correlation: 1.0
# 161: FEAT_A: 17113b36 FEAT_B: Bird Measurer (Assessment)_4110 - Correlation: 1.0
# 162: FEAT_A: 30614231 FEAT_B: Cauldron Filler (Assessment)_4020 - Correlation: 1.0
# 163: FEAT_A: 28a4eb9a FEAT_B: Dino Dive_3120 - Correlation: 1.0
# 164: FEAT_A: 37937459 FEAT_B: Sandcastle Builder (Activity)_4090 - Correlation: 1.0
# 165: FEAT_A: 2dc29e21 FEAT_B: All Star Sorting_4020 - Correlation: 1.0
# 166: FEAT_A: 5e812b27 FEAT_B: Sandcastle Builder (Activity)_4030 - Correlation: 1.0
# 167: FEAT_A: 5f0eb72c FEAT_B: Mushroom Sorter (Assessment)_4020 - Correlation: 1.0
# 168: FEAT_A: 5e3ea25a FEAT_B: Crystals Rule_4070 - Correlation: 1.0
# 169: FEAT_A: 04df9b66 FEAT_B: Cauldron Filler (Assessment)_3020 - Correlation: 1.0
# 170: FEAT_A: 29a42aea FEAT_B: Bubble Bath_4080 - Correlation: 1.0
# 171: FEAT_A: 9b4001e4 FEAT_B: Air Show_3021 - Correlation: 1.0
# 172: FEAT_A: 884228c8 FEAT_B: Fireworks (Activity)_4070 - Correlation: 1.0
# 173: FEAT_A: 3edf6747 FEAT_B: Cauldron Filler (Assessment)_4035 - Correlation: 1.0
# 174: FEAT_A: 587b5989 FEAT_B: All Star Sorting_4070 - Correlation: 1.0
# 175: FEAT_A: d122731b FEAT_B: Cart Balancer (Assessment)_4100 - Correlation: 1.0
# 176: FEAT_A: 3a4be871 FEAT_B: Flower Waterer (Activity)_4080 - Correlation: 1.0
# 177: FEAT_A: f28c589a FEAT_B: Air Show_3010 - Correlation: 1.0
# 178: FEAT_A: 763fc34e FEAT_B: Leaf Leader_3020 - Correlation: 1.0
# 179: FEAT_A: 90ea0bac FEAT_B: Bubble Bath_3020 - Correlation: 1.0
# 180: FEAT_A: 7d5c30a2 FEAT_B: Dino Dive_2060 - Correlation: 1.0
# 181: FEAT_A: 45d01abe FEAT_B: Bird Measurer (Assessment)_3021 - Correlation: 1.0
# 182: FEAT_A: 532a2afb FEAT_B: Cauldron Filler (Assessment)_2020 - Correlation: 1.0
# 183: FEAT_A: 4a09ace1 FEAT_B: Scrub-A-Dub_2083 - Correlation: 1.0
# 184: FEAT_A: 1325467d FEAT_B: Sandcastle Builder (Activity)_4070 - Correlation: 1.0
# 185: FEAT_A: 0db6d71d FEAT_B: Chest Sorter (Assessment)_4020 - Correlation: 1.0
# 186: FEAT_A: 92687c59 FEAT_B: Scrub-A-Dub_4090 - Correlation: 1.0
# 187: FEAT_A: 51102b85 FEAT_B: Bird Measurer (Assessment)_4030 - Correlation: 1.0
# 188: FEAT_A: 33505eae FEAT_B: Leaf Leader_3010 - Correlation: 1.0
# 189: FEAT_A: a16a373e FEAT_B: Bird Measurer (Assessment)_4070 - Correlation: 1.0
# 190: FEAT_A: 67aa2ada FEAT_B: Leaf Leader_4090 - Correlation: 1.0
# 191: FEAT_A: 1b54d27f FEAT_B: Watering Hole (Activity)_2010 - Correlation: 1.0
# 192: FEAT_A: 1c178d24 FEAT_B: Pan Balance_2030 - Correlation: 1.0
# 193: FEAT_A: 1bb5fbdb FEAT_B: Sandcastle Builder (Activity)_3110 - Correlation: 1.0
# 194: FEAT_A: 3babcb9b FEAT_B: Crystals Rule_3110 - Correlation: 1.0
# 195: FEAT_A: 13f56524 FEAT_B: Mushroom Sorter (Assessment)_4080 - Correlation: 1.0
# 196: FEAT_A: a1e4395d FEAT_B: Mushroom Sorter (Assessment)_3010 - Correlation: 1.0
# 197: FEAT_A: 51311d7a FEAT_B: Dino Drink_2000 - Correlation: 1.0
# 198: FEAT_A: 2a512369 FEAT_B: Leaf Leader_3110 - Correlation: 1.0
# 199: FEAT_A: 2b9272f4 FEAT_B: Scrub-A-Dub_3121 - Correlation: 1.0
# 200: FEAT_A: 828e68f9 FEAT_B: Cart Balancer (Assessment)_3110 - Correlation: 1.0
# 201: FEAT_A: 8b757ab8 FEAT_B: Crystals Rule_3120 - Correlation: 1.0
# 202: FEAT_A: beb0a7b9 FEAT_B: Fireworks (Activity)_3010 - Correlation: 1.0
# 203: FEAT_A: 5290eab1 FEAT_B: Cauldron Filler (Assessment)_3120 - Correlation: 1.0
# 204: FEAT_A: 99ea62f3 FEAT_B: Bubble Bath_2083 - Correlation: 1.0
# 205: FEAT_A: d38c2fd7 FEAT_B: Bird Measurer (Assessment)_4035 - Correlation: 1.0
# 206: FEAT_A: 8af75982 FEAT_B: Happy Camel_4020 - Correlation: 1.0
# 207: FEAT_A: b012cd7f FEAT_B: Leaf Leader_2030 - Correlation: 1.0
# 208: FEAT_A: a52b92d5 FEAT_B: Mushroom Sorter (Assessment)_3110 - Correlation: 1.0
# 209: FEAT_A: d2659ab4 FEAT_B: Air Show_2075 - Correlation: 1.0
# 210: FEAT_A: 9ee1c98c FEAT_B: Sandcastle Builder (Activity)_4021 - Correlation: 1.0
# 211: FEAT_A: e79f3763 FEAT_B: Bug Measurer (Activity)_4030 - Correlation: 1.0
# 212: FEAT_A: 9ce586dd FEAT_B: Chest Sorter (Assessment)_4035 - Correlation: 1.0
# 213: FEAT_A: f5b8c21a FEAT_B: Air Show_2030 - Correlation: 1.0
# 214: FEAT_A: 565a3990 FEAT_B: Bug Measurer (Activity)_4070 - Correlation: 1.0
# 215: FEAT_A: abc5811c FEAT_B: Happy Camel_4010 - Correlation: 1.0
# 216: FEAT_A: 15f99afc FEAT_B: Pan Balance_3110 - Correlation: 1.0
# 217: FEAT_A: 756e5507 FEAT_B: Chicken Balancer (Activity)_2000 - Correlation: 1.0
# 218: FEAT_A: 44cb4907 FEAT_B: Crystals Rule_3020 - Correlation: 1.0
# 219: FEAT_A: ab3136ba FEAT_B: Dino Dive_3110 - Correlation: 1.0
# 220: FEAT_A: a29c5338 FEAT_B: Dino Drink_3010 - Correlation: 1.0
# 221: FEAT_A: c58186bf FEAT_B: Sandcastle Builder (Activity)_4035 - Correlation: 1.0
# 222: FEAT_A: 93edfe2e FEAT_B: Crystals Rule_4090 - Correlation: 1.0
# 223: FEAT_A: cf82af56 FEAT_B: Scrub-A-Dub_4070 - Correlation: 1.0
# 224: FEAT_A: 99abe2bb FEAT_B: Bubble Bath_2080 - Correlation: 1.0
# 225: FEAT_A: 87d743c1 FEAT_B: Dino Dive_4010 - Correlation: 1.0
# 226: FEAT_A: 49ed92e9 FEAT_B: Watering Hole (Activity)_3010 - Correlation: 1.0
# 227: FEAT_A: ea321fb1 FEAT_B: Chicken Balancer (Activity)_3010 - Correlation: 1.0
# 228: FEAT_A: bc8f2793 FEAT_B: Pan Balance_4035 - Correlation: 1.0
# 229: FEAT_A: a1bbe385 FEAT_B: Air Show_3110 - Correlation: 1.0
# 230: FEAT_A: 3323d7e9 FEAT_B: Crystals Rule_2030 - Correlation: 1.0
# 231: FEAT_A: 84b0e0c8 FEAT_B: Chicken Balancer (Activity)_3110 - Correlation: 1.0
# 232: FEAT_A: 6f4adc4b FEAT_B: Bubble Bath_3021 - Correlation: 1.0
# 233: FEAT_A: 3dcdda7f FEAT_B: Chest Sorter (Assessment)_3010 - Correlation: 1.0
# 234: FEAT_A: e7e44842 FEAT_B: Watering Hole (Activity)_4090 - Correlation: 1.0
# 235: FEAT_A: 3ee399c3 FEAT_B: Cauldron Filler (Assessment)_4070 - Correlation: 1.0
# 236: FEAT_A: c6971acf FEAT_B: Dino Drink_2060 - Correlation: 1.0
# 237: FEAT_A: 77c76bc5 FEAT_B: Cauldron Filler (Assessment)_4090 - Correlation: 1.0
# 238: FEAT_A: 48349b14 FEAT_B: Crystals Rule_2000 - Correlation: 1.0
# 239: FEAT_A: ea296733 FEAT_B: Chest Sorter (Assessment)_3020 - Correlation: 1.0
# 240: FEAT_A: cb1178ad FEAT_B: Chest Sorter (Assessment)_4090 - Correlation: 1.0
# 241: FEAT_A: 91561152 FEAT_B: Cauldron Filler (Assessment)_4025 - Correlation: 1.0
# 242: FEAT_A: 2dcad279 FEAT_B: Cauldron Filler (Assessment)_3110 - Correlation: 1.0
# 243: FEAT_A: bcceccc6 FEAT_B: Air Show_4070 - Correlation: 1.0
# 244: FEAT_A: 3bfd1a65 FEAT_B: Mushroom Sorter (Assessment)_2000 - Correlation: 1.0
# 245: FEAT_A: 9c5ef70c FEAT_B: Pan Balance_2000 - Correlation: 1.0
# 246: FEAT_A: 499edb7c FEAT_B: Chicken Balancer (Activity)_4020 - Correlation: 1.0
# 247: FEAT_A: 0086365d FEAT_B: Pan Balance_4010 - Correlation: 1.0
# 248: FEAT_A: e4d32835 FEAT_B: Pan Balance_4080 - Correlation: 1.0
# 249: FEAT_A: 3afde5dd FEAT_B: Leaf Leader_3021 - Correlation: 1.0
# 250: FEAT_A: 392e14df FEAT_B: Cauldron Filler (Assessment)_4100 - Correlation: 1.0
# 251: FEAT_A: 00c73085 FEAT_B: Dino Dive_2030 - Correlation: 1.0
# 252: FEAT_A: a6d66e51 FEAT_B: Watering Hole (Activity)_5000 - Correlation: 1.0
# 253: FEAT_A: 6c517a88 FEAT_B: Dino Drink_4070 - Correlation: 1.0
# 254: FEAT_A: 6f8106d9 FEAT_B: Dino Drink_4090 - Correlation: 1.0
# 255: FEAT_A: 5be391b5 FEAT_B: Dino Drink_4010 - Correlation: 1.0
# 256: FEAT_A: a76029ee FEAT_B: Bird Measurer (Assessment)_4040 - Correlation: 1.0
# 257: FEAT_A: 0413e89d FEAT_B: Bubble Bath_3010 - Correlation: 1.0
# 258: FEAT_A: 160654fd FEAT_B: Mushroom Sorter (Assessment)_3020 - Correlation: 1.0
# 259: FEAT_A: 2c4e6db0 FEAT_B: All Star Sorting_2020 - Correlation: 1.0
# 260: FEAT_A: 16667cc5 FEAT_B: Chicken Balancer (Activity)_4080 - Correlation: 1.0
# 261: FEAT_A: 8ac7cce4 FEAT_B: Leaf Leader_2000 - Correlation: 1.0
# 262: FEAT_A: df4940d3 FEAT_B: Bottle Filler (Activity)_3110 - Correlation: 1.0
# 263: FEAT_A: 77ead60d FEAT_B: Dino Drink_3021 - Correlation: 1.0
# 264: FEAT_A: 804ee27f FEAT_B: Pan Balance_4020 - Correlation: 1.0
# 265: FEAT_A: 3d0b9317 FEAT_B: Chest Sorter (Assessment)_4040 - Correlation: 1.0
# 266: FEAT_A: ec138c1c FEAT_B: Bird Measurer (Assessment)_2020 - Correlation: 1.0
# 267: FEAT_A: 562cec5f FEAT_B: Chest Sorter (Assessment)_4025 - Correlation: 1.0
# 268: FEAT_A: d3f1e122 FEAT_B: Bottle Filler (Activity)_4035 - Correlation: 1.0
# 269: FEAT_A: b74258a0 FEAT_B: ecaab346 - Correlation: 1.0
# 270: FEAT_A: b7530680 FEAT_B: Bottle Filler (Activity)_2020 - Correlation: 1.0
# 271: FEAT_A: 363d3849 FEAT_B: All Star Sorting_3010 - Correlation: 1.0
# 272: FEAT_A: bdf49a58 FEAT_B: Bird Measurer (Assessment)_3110 - Correlation: 1.0
# 273: FEAT_A: c277e121 FEAT_B: All Star Sorting_3020 - Correlation: 1.0
# 274: FEAT_A: 47efca07 FEAT_B: Bottle Filler (Activity)_4090 - Correlation: 1.0
# 275: FEAT_A: 93b353f2 FEAT_B: Chest Sorter (Assessment)_4100 - Correlation: 1.0
# 276: FEAT_A: de26c3a6 FEAT_B: Flower Waterer (Activity)_4020 - Correlation: 1.0
# 277: FEAT_A: b88f38da FEAT_B: Fireworks (Activity)_3110 - Correlation: 1.0
# 278: FEAT_A: a5be6304 FEAT_B: Mushroom Sorter (Assessment)_2010 - Correlation: 1.0
# 279: FEAT_A: 4b5efe37 FEAT_B: All Star Sorting_4010 - Correlation: 1.0
# 280: FEAT_A: 155f62a4 FEAT_B: Chest Sorter (Assessment)_2000 - Correlation: 1.0
# 281: FEAT_A: ecaab346 FEAT_B: Cart Balancer (Assessment)_3121 - Correlation: 1.0
# 282: FEAT_A: Welcome to Lost Lagoon! FEAT_B: Welcome to Lost Lagoon!_2000 - Correlation: 1.0
# 283: FEAT_A: Magma Peak - Level 2 FEAT_B: Magma Peak - Level 2_2000 - Correlation: 1.0
# 284: FEAT_A: Balancing Act FEAT_B: Balancing Act_2000 - Correlation: 1.0
# 285: FEAT_A: Honey Cake FEAT_B: Honey Cake_2000 - Correlation: 1.0
# 286: FEAT_A: Treasure Map FEAT_B: Treasure Map_2000 - Correlation: 1.0
# 287: FEAT_A: Crystal Caves - Level 1 FEAT_B: Crystal Caves - Level 1_2000 - Correlation: 1.0
# 288: FEAT_A: Tree Top City - Level 2 FEAT_B: Tree Top City - Level 2_2000 - Correlation: 1.0
# 289: FEAT_A: Lifting Heavy Things FEAT_B: Lifting Heavy Things_2000 - Correlation: 1.0
# 290: FEAT_A: Rulers FEAT_B: Rulers_2000 - Correlation: 1.0
# 291: FEAT_A: Slop Problem FEAT_B: Slop Problem_2000 - Correlation: 1.0
# 292: FEAT_A: Tree Top City - Level 1 FEAT_B: Tree Top City - Level 1_2000 - Correlation: 1.0
# 293: FEAT_A: Cauldron Filler (Assessment) FEAT_B: Assessment_MAGMAPEAK - Correlation: 1.0
# 294: FEAT_A: Magma Peak - Level 1 FEAT_B: Magma Peak - Level 1_2000 - Correlation: 1.0
# 295: FEAT_A: Costume Box FEAT_B: Costume Box_2000 - Correlation: 1.0
# 296: FEAT_A: 12 Monkeys FEAT_B: 12 Monkeys_2000 - Correlation: 1.0
# 297: FEAT_A: Pirate's Tale FEAT_B: Pirate's Tale_2000 - Correlation: 1.0
# 298: FEAT_A: Egg Dropper (Activity)_2000 FEAT_B: Egg Dropper (Activity)_2020 - Correlation: 1.0
# 299: FEAT_A: Cart Balancer (Assessment)_3121 FEAT_B: Cart Balancer (Assessment)_2030 - Correlation: 1.0
# 300: FEAT_A: Chest Sorter (Assessment)_3120 FEAT_B: chest_assessment_uncorrect_sum - Correlation: 1.0
# 301: FEAT_A: Chest Sorter (Assessment)_2000 FEAT_B: Chest Sorter (Assessment)_2020 - Correlation: 1.0
# 302: FEAT_A: Chest Sorter (Assessment)_2010 FEAT_B: Chest Sorter (Assessment)_2030 - Correlation: 1.0
# 303: FEAT_A: Welcome to Lost Lagoon!_2000 FEAT_B: Clip_NONE - Correlation: 1.0

# %%
to_exclude = []
ajusted_test = reduce_test.copy()
for feature in ajusted_test.columns:
    if feature not in ['accuracy_group', 'installation_id', 'accuracy_group', 'session_title']:
        data = reduce_train[feature]
        train_mean = data.mean()
        data = ajusted_test[feature] 
        test_mean = data.mean()
        try:
            ajust_factor = train_mean / test_mean
            if ajust_factor > 10 or ajust_factor < 0.1:
                to_exclude.append(feature)
                print(feature, train_mean, test_mean)
            else:
                ajusted_test[feature] *= ajust_factor
        except:
            to_exclude.append(feature)
            print(feature, train_mean, test_mean)
# Out:
# acc_Cart Balancer (Assessment) -0.04020325710970116 -0.47065833333333346
# 2ec694de 0.008988128886376484 0.0
# eb2c19cd 0.17382702091577162 0.008
# 611485c5 0.0013566986998304127 0.0
# dcb1663e 0.0 0.0
# ab4ec3a4 0.0009044657998869418 0.0
# a8cc6fec 0.0 0.0
# 119b5b02 0.0002826455624646693 0.0
# 7fd1ac25 0.01978518937252685 0.0
# 003cd2ee 0.0 0.0
# 5dc079d8 0.0 0.0
# bfc77bd6 0.012832108535895986 0.0
# 29a42aea 0.004070096099491238 0.0
# 6aeafed4 0.14703222159412097 0.008
# ecc6157f 0.007292255511588468 0.0
# 1b54d27f 0.0007348784624081402 0.0
# 13f56524 0.04392312040700961 0.0
# 17ca3959 0.0 0.0
# 01ca3a3c 0.0004522328999434709 0.0
# 0ce40006 0.0008479366873940079 0.0
# 4074bac2 0.0 0.0
# e4d32835 0.0013001695873374789 0.0
# Clip_gametime 0.0 0.0
# Mushroom Sorter (Assessment)_4080 0.04392312040700961 0.0
# Pan Balance_2010 0.0 0.0
# Dino Drink_4080 0.0009044657998869418 0.0
# Chest Sorter (Assessment)_4080 0.012832108535895986 0.0
# Egg Dropper (Activity)_4080 0.01978518937252685 0.0
# Air Show_4080 0.0 0.0
# Dino Dive_4080 0.0002826455624646693 0.0
# Crystals Rule_2010 0.0 0.0
# Bug Measurer (Activity)_4080 0.008988128886376484 0.0
# Bottle Filler (Activity)_2010 0.0 0.0
# Mushroom Sorter (Assessment)_4090 0.17382702091577162 0.008
# Scrub-A-Dub_4080 0.0 0.0
# Happy Camel_4080 0.0008479366873940079 0.0
# Pan Balance_4080 0.0013001695873374789 0.0
# Sandcastle Builder (Activity)_2010 0.0 0.0
# Fireworks (Activity)_4080 0.0013566986998304127 0.0
# Bubble Bath_4080 0.004070096099491238 0.0
# Leaf Leader_4080 0.0004522328999434709 0.0
# Bubble Bath_4090 0.14703222159412097 0.008
# Watering Hole (Activity)_2010 0.0007348784624081402 0.0
# Cart Balancer (Assessment)_4080 0.007292255511588468 0.0
# Cauldron Filler (Assessment)_4020_accuracy 2.303730460456184e+210 5.080517549278432e+102
# Mushroom Sorter (Assessment)_4020_accuracy 3.681198231410178e+215 2.1682950808824264e+77
# Bird Measurer (Assessment)_4020_accuracy 4.847657130090902e+214 1.1047334545798042e+28
# Chest Sorter (Assessment)_4020_accuracy 5.535196124656113e+211 5.156518164058864e+99
# Cauldron_Filler_4025 0.0 0.0

# %%
features = [x for x in features if x not in (to_exclude + to_remove)]
reduce_train[features].shape
# Out:
# (17690, 585)

# %%
y_lgb_pred = run_lgb_regression(reduce_train, ajusted_test, features, 5)
# Out:
# Fold 1
# /opt/conda/lib/python3.6/site-packages/lightgbm/engine.py:148: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# /opt/conda/lib/python3.6/site-packages/lightgbm/engine.py:153: UserWarning: Found `early_stopping_rounds` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# /opt/conda/lib/python3.6/site-packages/lightgbm/basic.py:1243: UserWarning: Using categorical_feature in Dataset.
#   warnings.warn('Using categorical_feature in Dataset.')
# Training until validation scores don't improve for 200 rounds
# [100]	training's rmse: 1.03406	valid_1's rmse: 1.05361
# [200]	training's rmse: 0.965606	valid_1's rmse: 1.00414
# [300]	training's rmse: 0.930528	valid_1's rmse: 0.986883
# [400]	training's rmse: 0.905745	valid_1's rmse: 0.980045
# [500]	training's rmse: 0.886048	valid_1's rmse: 0.97716
# [600]	training's rmse: 0.86856	valid_1's rmse: 0.975735
# [700]	training's rmse: 0.852831	valid_1's rmse: 0.974803
# [800]	training's rmse: 0.838142	valid_1's rmse: 0.974012
# [900]	training's rmse: 0.824438	valid_1's rmse: 0.97401
# [1000]	training's rmse: 0.81152	valid_1's rmse: 0.973486
# [1100]	training's rmse: 0.799132	valid_1's rmse: 0.973672
# [1200]	training's rmse: 0.787168	valid_1's rmse: 0.973747
# Early stopping, best iteration is:
# [1022]	training's rmse: 0.808646	valid_1's rmse: 0.973233
# Fold 2
# Training until validation scores don't improve for 200 rounds
# [100]	training's rmse: 1.03208	valid_1's rmse: 1.05194
# [200]	training's rmse: 0.962957	valid_1's rmse: 1.00646
# [300]	training's rmse: 0.927371	valid_1's rmse: 0.993027
# [400]	training's rmse: 0.90232	valid_1's rmse: 0.989299
# [500]	training's rmse: 0.882566	valid_1's rmse: 0.988281
# [600]	training's rmse: 0.86508	valid_1's rmse: 0.987863
# [700]	training's rmse: 0.849428	valid_1's rmse: 0.987842
# [800]	training's rmse: 0.835086	valid_1's rmse: 0.988355
# [900]	training's rmse: 0.821604	valid_1's rmse: 0.98793
# Early stopping, best iteration is:
# [715]	training's rmse: 0.847227	valid_1's rmse: 0.987623
# Fold 3
# Training until validation scores don't improve for 200 rounds
# [100]	training's rmse: 1.03204	valid_1's rmse: 1.05465
# [200]	training's rmse: 0.963035	valid_1's rmse: 1.00767
# [300]	training's rmse: 0.928314	valid_1's rmse: 0.993261
# [400]	training's rmse: 0.903921	valid_1's rmse: 0.987405
# [500]	training's rmse: 0.883932	valid_1's rmse: 0.985248
# [600]	training's rmse: 0.866561	valid_1's rmse: 0.984254
# [700]	training's rmse: 0.851064	valid_1's rmse: 0.983516
# [800]	training's rmse: 0.836631	valid_1's rmse: 0.983649
# [900]	training's rmse: 0.823013	valid_1's rmse: 0.984033
# Early stopping, best iteration is:
# [716]	training's rmse: 0.848707	valid_1's rmse: 0.983412
# Fold 4
# Training until validation scores don't improve for 200 rounds
# [100]	training's rmse: 1.03197	valid_1's rmse: 1.05596
# [200]	training's rmse: 0.963173	valid_1's rmse: 1.01057
# [300]	training's rmse: 0.927863	valid_1's rmse: 0.995299
# [400]	training's rmse: 0.903466	valid_1's rmse: 0.989933
# [500]	training's rmse: 0.883654	valid_1's rmse: 0.987162
# [600]	training's rmse: 0.866324	valid_1's rmse: 0.986123
# [700]	training's rmse: 0.850689	valid_1's rmse: 0.985513
# [800]	training's rmse: 0.836009	valid_1's rmse: 0.984796
# [900]	training's rmse: 0.822327	valid_1's rmse: 0.984508
# [1000]	training's rmse: 0.809521	valid_1's rmse: 0.984834
# Early stopping, best iteration is:
# [899]	training's rmse: 0.822449	valid_1's rmse: 0.984497
# Fold 5
# Training until validation scores don't improve for 200 rounds
# [100]	training's rmse: 1.03151	valid_1's rmse: 1.05665
# [200]	training's rmse: 0.963303	valid_1's rmse: 1.01064
# [300]	training's rmse: 0.928536	valid_1's rmse: 0.994763
# [400]	training's rmse: 0.904061	valid_1's rmse: 0.98769
# [500]	training's rmse: 0.88412	valid_1's rmse: 0.984104
# [600]	training's rmse: 0.867154	valid_1's rmse: 0.98231
# [700]	training's rmse: 0.851511	valid_1's rmse: 0.981565
# [800]	training's rmse: 0.836931	valid_1's rmse: 0.980891
# [900]	training's rmse: 0.82333	valid_1's rmse: 0.980512
# [1000]	training's rmse: 0.810386	valid_1's rmse: 0.980376
# [1100]	training's rmse: 0.7983	valid_1's rmse: 0.980647
# Early stopping, best iteration is:
# [943]	training's rmse: 0.817564	valid_1's rmse: 0.980212
# Our oof cohen kappa score is:  0.5930627280077454

# %%
y_xgb_pred = run_xgb_regression(reduce_train, ajusted_test, features, 5)
# Out:
# Fold 1
# /opt/conda/lib/python3.6/site-packages/xgboost/core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [0]	train-rmse:1.8563	val-rmse:1.8569
# Multiple eval metrics have been passed: 'val-rmse' will be used for early stopping.
#
# Will train until val-rmse hasn't improved in 200 rounds.
# [100]	train-rmse:1.01074	val-rmse:1.1539
# [200]	train-rmse:0.732025	val-rmse:1.0112
# [300]	train-rmse:0.617319	val-rmse:0.985649
# [400]	train-rmse:0.556298	val-rmse:0.981975
# [500]	train-rmse:0.514566	val-rmse:0.981475
# [600]	train-rmse:0.487925	val-rmse:0.981932
# [700]	train-rmse:0.462341	val-rmse:0.982774
# Stopping. Best iteration:
# [538]	train-rmse:0.504081	val-rmse:0.98138
#
# Fold 2
# [0]	train-rmse:1.8562	val-rmse:1.85766
# Multiple eval metrics have been passed: 'val-rmse' will be used for early stopping.
#
# Will train until val-rmse hasn't improved in 200 rounds.
# [100]	train-rmse:1.00356	val-rmse:1.17223
# [200]	train-rmse:0.721983	val-rmse:1.02962
# [300]	train-rmse:0.608839	val-rmse:1.00251
# [400]	train-rmse:0.546016	val-rmse:0.996907
# [500]	train-rmse:0.506036	val-rmse:0.995883
# [600]	train-rmse:0.478525	val-rmse:0.99698
# [700]	train-rmse:0.451786	val-rmse:0.997986
# Stopping. Best iteration:
# [504]	train-rmse:0.504955	val-rmse:0.995824
#
# Fold 3
# [0]	train-rmse:1.85615	val-rmse:1.85733
# Multiple eval metrics have been passed: 'val-rmse' will be used for early stopping.
#
# Will train until val-rmse hasn't improved in 200 rounds.
# [100]	train-rmse:1.00429	val-rmse:1.16202
# [200]	train-rmse:0.723674	val-rmse:1.02159
# [300]	train-rmse:0.610775	val-rmse:0.99968
# [400]	train-rmse:0.553181	val-rmse:0.997298
# [500]	train-rmse:0.511555	val-rmse:0.998169
# [600]	train-rmse:0.486099	val-rmse:0.999079
# Stopping. Best iteration:
# [418]	train-rmse:0.544448	val-rmse:0.997177
#
# Fold 4
# [0]	train-rmse:1.8562	val-rmse:1.85734
# Multiple eval metrics have been passed: 'val-rmse' will be used for early stopping.
#
# Will train until val-rmse hasn't improved in 200 rounds.
# [100]	train-rmse:1.00662	val-rmse:1.15946
# [200]	train-rmse:0.7279	val-rmse:1.01899
# [300]	train-rmse:0.614067	val-rmse:0.994805
# [400]	train-rmse:0.553451	val-rmse:0.991302
# [500]	train-rmse:0.511487	val-rmse:0.991519
# [600]	train-rmse:0.482817	val-rmse:0.992086
# Stopping. Best iteration:
# [439]	train-rmse:0.534357	val-rmse:0.99098
#
# Fold 5
# [0]	train-rmse:1.85617	val-rmse:1.85764
# Multiple eval metrics have been passed: 'val-rmse' will be used for early stopping.
#
# Will train until val-rmse hasn't improved in 200 rounds.
# [100]	train-rmse:1.01046	val-rmse:1.15901
# [200]	train-rmse:0.730975	val-rmse:1.01682
# [300]	train-rmse:0.61557	val-rmse:0.992939
# [400]	train-rmse:0.551339	val-rmse:0.988768
# [500]	train-rmse:0.504616	val-rmse:0.988623
# [600]	train-rmse:0.476682	val-rmse:0.988748
# Stopping. Best iteration:
# [461]	train-rmse:0.520324	val-rmse:0.988314
#
# Our oof cohen kappa score is:  0.583327729064747

# %%
lgb_weight = 1
final_pred = y_lgb_pred * lgb_weight + y_xgb_pred * (1 - lgb_weight)
print(final_pred.shape, y_lgb_pred.shape, y_xgb_pred.shape)
# Out:
# (1000,) (1000,) (1000,)

# %%
dist = Counter(reduce_train['accuracy_group'])
for k in dist:
    dist[k] /= len(reduce_train)
reduce_train['accuracy_group'].hist()

acum = 0
bound = {}
for i in range(3):
    acum += dist[i]
    bound[i] = np.percentile(final_pred, acum * 100)
print(bound)

def classify(x):
    if x <= bound[0]:
        return 0
    elif x <= bound[1]:
        return 1
    elif x <= bound[2]:
        return 2
    else:
        return 3
    
final_pred = np.array(list(map(classify, final_pred)))

sample_submission['accuracy_group'] = final_pred.astype(int)
sample_submission.to_csv('submission.csv', index=False)
sample_submission['accuracy_group'].value_counts(normalize=True)
# Out:
# {0: 1.2968855569672708, 1: 1.7096128624015174, 2: 1.934691492679033}
# 3    0.500
# 0    0.239
# 1    0.136
# 2    0.125
# Name: accuracy_group, dtype: float64
